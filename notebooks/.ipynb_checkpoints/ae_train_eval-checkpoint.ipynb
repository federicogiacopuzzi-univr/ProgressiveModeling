# %%
import sys
import os
# Getting src path to import modules
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Adding src path to the system path, if not already added
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from dl_models import LinearAE as ae

# %%
# Time series data for a specific building (Building_1.csv/Building_2.csv/Building_3.csv).
electricity_data = pd.read_csv("../data/citylearn_challenge_2023_phase_1/Building_1.csv")

# Carbon intensity data.
carbon_data = pd.read_csv("../data/citylearn_challenge_2023_phase_1/carbon_intensity.csv")

# Pricing data (CityLearn Challenge 2023).
pricing_data = pd.read_csv("../data/citylearn_challenge_2023_phase_1/pricing.csv")

# Weather data (CityLearn Challenge 2023).
weather_data = pd.read_csv("../data/citylearn_challenge_2023_phase_1/weather.csv")

# Concatenate multiple datasets along the columns (axis=1) to create a single dataset.
df = pd.concat([electricity_data, carbon_data, pricing_data, weather_data], axis=1)

# Displaying the last 5 samples of the dataframe to show its structure.
df.tail()
# Out:
#      month  hour  day_type  daylight_savings_status  \
# 715      6    20         6                        0
# 716      6    21         6                        0
# 717      6    22         6                        0
# 718      6    23         6                        0
# 719      6    24         6                        0
#
#      indoor_dry_bulb_temperature  average_unmet_cooling_setpoint_difference  \
# 715                    24.468618                                   0.024173
# 716                    24.444859                                   0.000415
# 717                    24.444464                                   0.000019
# 718                    24.444452                                   0.000009
# 719                    21.812447                                   0.145780
#
#      indoor_relative_humidity  non_shiftable_load  dhw_demand  cooling_demand  \
# 715                 54.277103            0.442291    0.398354        5.189857
# 716                 54.351337            0.990416    0.199180        4.550693
# 717                 54.532566            1.563732    0.000000        4.043389
# 718                 54.647182            0.421510    0.000000        3.268111
# 719                 63.234272            0.374985    0.000000        6.492827
#
#      ...  outdoor_dry_bulb_temperature_predicted_24h  \
# 715  ...                                   32.905895
# 716  ...                                   32.669003
# 717  ...                                   29.979940
# 718  ...                                   28.337627
# 719  ...                                   25.415920
#
#      outdoor_relative_humidity_predicted_6h  \
# 715                               89.465866
# 716                               87.158066
# 717                              100.000000
# 718                               90.768420
# 719                               82.899440
#
#      outdoor_relative_humidity_predicted_12h  \
# 715                                73.861000
# 716                                66.389130
# 717                                58.228535
# 718                                35.361465
# 719                                47.129494
#
#      outdoor_relative_humidity_predicted_24h  \
# 715                                40.875510
# 716                                64.036320
# 717                                51.990180
# 718                                60.445404
# 719                                56.078560
#
#      diffuse_solar_irradiance_predicted_6h  \
# 715                                    0.0
# 716                                    0.0
# 717                                    0.0
# 718                                    0.0
# 719                                    0.0
#
#      diffuse_solar_irradiance_predicted_12h  \
# 715                               110.15520
# 716                               216.20418
# 717                               259.28485
# 718                               272.40073
# 719                               129.96535
#
#      diffuse_solar_irradiance_predicted_24h  \
# 715                                     0.0
# 716                                     0.0
# 717                                     0.0
# 718                                     0.0
# 719                                     0.0
#
#      direct_solar_irradiance_predicted_6h  \
# 715                                   0.0
# 716                                   0.0
# 717                                   0.0
# 718                                   0.0
# 719                                   0.0
#
#      direct_solar_irradiance_predicted_12h  \
# 715                              271.32200
# 716                              151.80556
# 717                              374.21823
# 718                              582.50290
# 719                              842.14680
#
#      direct_solar_irradiance_predicted_24h
# 715                                    0.0
# 716                                    0.0
# 717                                    0.0
# 718                                    0.0
# 719                                    0.0
#
# [5 rows x 36 columns]

# %%
# List of features used for training the autoencoder.
features = ['month', 'hour', 'day_type', 'daylight_savings_status', 'indoor_dry_bulb_temperature', 'average_unmet_cooling_setpoint_difference', 
            'indoor_relative_humidity', 'non_shiftable_load', 'dhw_demand', 'cooling_demand', 'heating_demand', 'solar_generation', 'occupant_count', 
            'indoor_dry_bulb_temperature_set_point', 'hvac_mode', 'carbon_intensity', 'electricity_pricing', 
            'electricity_pricing_predicted_6h', 'electricity_pricing_predicted_12h', 'electricity_pricing_predicted_24h', 
            'outdoor_dry_bulb_temperature', 'outdoor_relative_humidity', 'diffuse_solar_irradiance', 'direct_solar_irradiance', 
            'outdoor_dry_bulb_temperature_predicted_6h', 'outdoor_dry_bulb_temperature_predicted_12h', 'outdoor_dry_bulb_temperature_predicted_24h', 
            'outdoor_relative_humidity_predicted_6h', 'outdoor_relative_humidity_predicted_12h', 'outdoor_relative_humidity_predicted_24h', 
            'diffuse_solar_irradiance_predicted_6h', 'diffuse_solar_irradiance_predicted_12h', 'diffuse_solar_irradiance_predicted_24h', 
            'direct_solar_irradiance_predicted_6h', 'direct_solar_irradiance_predicted_12h', 'direct_solar_irradiance_predicted_24h']

# %%
real, pred = ae.Autoencoder(df, features)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 16ms/step - loss: 1.1687 - mean_absolute_error: 0.9527 - val_loss: 1.0975 - val_mean_absolute_error: 0.9212
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 1.0228 - mean_absolute_error: 0.8905 - val_loss: 0.8702 - val_mean_absolute_error: 0.8206
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7447 - mean_absolute_error: 0.7607 - val_loss: 0.6019 - val_mean_absolute_error: 0.6877
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5715 - mean_absolute_error: 0.6704 - val_loss: 0.5449 - val_mean_absolute_error: 0.6529
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5486 - mean_absolute_error: 0.6560 - val_loss: 0.5383 - val_mean_absolute_error: 0.6471
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5448 - mean_absolute_error: 0.6526 - val_loss: 0.5358 - val_mean_absolute_error: 0.6455
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5427 - mean_absolute_error: 0.6511 - val_loss: 0.5331 - val_mean_absolute_error: 0.6426
# Epoch 8/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5391 - mean_absolute_error: 0.6469 - val_loss: 0.5290 - val_mean_absolute_error: 0.6380
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5350 - mean_absolute_error: 0.6428 - val_loss: 0.5253 - val_mean_absolute_error: 0.6342
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5329 - mean_absolute_error: 0.6404 - val_loss: 0.5235 - val_mean_absolute_error: 0.6315
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5312 - mean_absolute_error: 0.6383 - val_loss: 0.5219 - val_mean_absolute_error: 0.6299
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5293 - mean_absolute_error: 0.6363 - val_loss: 0.5182 - val_mean_absolute_error: 0.6261
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5263 - mean_absolute_error: 0.6331 - val_loss: 0.5155 - val_mean_absolute_error: 0.6227
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5224 - mean_absolute_error: 0.6290 - val_loss: 0.5117 - val_mean_absolute_error: 0.6182
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5185 - mean_absolute_error: 0.6240 - val_loss: 0.5089 - val_mean_absolute_error: 0.6141
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5162 - mean_absolute_error: 0.6212 - val_loss: 0.5074 - val_mean_absolute_error: 0.6128
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5147 - mean_absolute_error: 0.6191 - val_loss: 0.5065 - val_mean_absolute_error: 0.6113
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5136 - mean_absolute_error: 0.6176 - val_loss: 0.5055 - val_mean_absolute_error: 0.6105
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5123 - mean_absolute_error: 0.6163 - val_loss: 0.5039 - val_mean_absolute_error: 0.6087
# Epoch 20/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5106 - mean_absolute_error: 0.6142 - val_loss: 0.5028 - val_mean_absolute_error: 0.6069
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5096 - mean_absolute_error: 0.6126 - val_loss: 0.5024 - val_mean_absolute_error: 0.6060
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5090 - mean_absolute_error: 0.6115 - val_loss: 0.5019 - val_mean_absolute_error: 0.6054
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5083 - mean_absolute_error: 0.6110 - val_loss: 0.5014 - val_mean_absolute_error: 0.6047
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5078 - mean_absolute_error: 0.6102 - val_loss: 0.5011 - val_mean_absolute_error: 0.6044
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5072 - mean_absolute_error: 0.6094 - val_loss: 0.5003 - val_mean_absolute_error: 0.6033
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5067 - mean_absolute_error: 0.6089 - val_loss: 0.5001 - val_mean_absolute_error: 0.6028
# Epoch 27/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5061 - mean_absolute_error: 0.6080 - val_loss: 0.4994 - val_mean_absolute_error: 0.6020
# Epoch 28/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5054 - mean_absolute_error: 0.6072 - val_loss: 0.4987 - val_mean_absolute_error: 0.6015
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5048 - mean_absolute_error: 0.6065 - val_loss: 0.4983 - val_mean_absolute_error: 0.6007
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5042 - mean_absolute_error: 0.6055 - val_loss: 0.4975 - val_mean_absolute_error: 0.5992
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5034 - mean_absolute_error: 0.6045 - val_loss: 0.4967 - val_mean_absolute_error: 0.5982
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5026 - mean_absolute_error: 0.6032 - val_loss: 0.4958 - val_mean_absolute_error: 0.5970
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5018 - mean_absolute_error: 0.6018 - val_loss: 0.4946 - val_mean_absolute_error: 0.5949
# Epoch 34/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5008 - mean_absolute_error: 0.6002 - val_loss: 0.4935 - val_mean_absolute_error: 0.5931
# Epoch 35/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4999 - mean_absolute_error: 0.5988 - val_loss: 0.4929 - val_mean_absolute_error: 0.5923
# Epoch 36/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4992 - mean_absolute_error: 0.5977 - val_loss: 0.4922 - val_mean_absolute_error: 0.5913
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4985 - mean_absolute_error: 0.5966 - val_loss: 0.4911 - val_mean_absolute_error: 0.5895
# Epoch 38/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4974 - mean_absolute_error: 0.5953 - val_loss: 0.4902 - val_mean_absolute_error: 0.5880
# Epoch 39/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4968 - mean_absolute_error: 0.5944 - val_loss: 0.4898 - val_mean_absolute_error: 0.5879
# Epoch 40/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4960 - mean_absolute_error: 0.5934 - val_loss: 0.4882 - val_mean_absolute_error: 0.5857
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4950 - mean_absolute_error: 0.5919 - val_loss: 0.4870 - val_mean_absolute_error: 0.5842
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4940 - mean_absolute_error: 0.5911 - val_loss: 0.4862 - val_mean_absolute_error: 0.5831
# Epoch 43/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4937 - mean_absolute_error: 0.5905 - val_loss: 0.4854 - val_mean_absolute_error: 0.5822
# Epoch 44/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4928 - mean_absolute_error: 0.5893 - val_loss: 0.4848 - val_mean_absolute_error: 0.5814
# Epoch 45/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4923 - mean_absolute_error: 0.5888 - val_loss: 0.4843 - val_mean_absolute_error: 0.5805
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4918 - mean_absolute_error: 0.5879 - val_loss: 0.4840 - val_mean_absolute_error: 0.5804
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4916 - mean_absolute_error: 0.5878 - val_loss: 0.4839 - val_mean_absolute_error: 0.5801
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4913 - mean_absolute_error: 0.5872 - val_loss: 0.4835 - val_mean_absolute_error: 0.5795
# Epoch 49/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4908 - mean_absolute_error: 0.5866 - val_loss: 0.4831 - val_mean_absolute_error: 0.5786
# Epoch 50/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4905 - mean_absolute_error: 0.5860 - val_loss: 0.4825 - val_mean_absolute_error: 0.5781
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4892 - mean_absolute_error: 0.5843 - val_loss: 0.4803 - val_mean_absolute_error: 0.5754
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4884 - mean_absolute_error: 0.5836 - val_loss: 0.4795 - val_mean_absolute_error: 0.5743
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4876 - mean_absolute_error: 0.5821 - val_loss: 0.4790 - val_mean_absolute_error: 0.5736
# Epoch 54/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4872 - mean_absolute_error: 0.5817 - val_loss: 0.4789 - val_mean_absolute_error: 0.5732
# Epoch 55/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4869 - mean_absolute_error: 0.5810 - val_loss: 0.4786 - val_mean_absolute_error: 0.5731
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4867 - mean_absolute_error: 0.5809 - val_loss: 0.4781 - val_mean_absolute_error: 0.5717
# Epoch 57/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4864 - mean_absolute_error: 0.5801 - val_loss: 0.4779 - val_mean_absolute_error: 0.5715
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4861 - mean_absolute_error: 0.5795 - val_loss: 0.4777 - val_mean_absolute_error: 0.5708
# Epoch 59/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4859 - mean_absolute_error: 0.5792 - val_loss: 0.4775 - val_mean_absolute_error: 0.5707
# Epoch 60/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4858 - mean_absolute_error: 0.5788 - val_loss: 0.4774 - val_mean_absolute_error: 0.5702
# Epoch 61/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.4856 - mean_absolute_error: 0.5785 - val_loss: 0.4773 - val_mean_absolute_error: 0.5697
# Epoch 62/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4854 - mean_absolute_error: 0.5781 - val_loss: 0.4770 - val_mean_absolute_error: 0.5693
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4852 - mean_absolute_error: 0.5778 - val_loss: 0.4768 - val_mean_absolute_error: 0.5690
# Epoch 64/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4851 - mean_absolute_error: 0.5772 - val_loss: 0.4767 - val_mean_absolute_error: 0.5687
# Epoch 65/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.4849 - mean_absolute_error: 0.5770 - val_loss: 0.4767 - val_mean_absolute_error: 0.5687
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4848 - mean_absolute_error: 0.5766 - val_loss: 0.4766 - val_mean_absolute_error: 0.5686
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4847 - mean_absolute_error: 0.5764 - val_loss: 0.4764 - val_mean_absolute_error: 0.5682
# Epoch 68/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4845 - mean_absolute_error: 0.5759 - val_loss: 0.4763 - val_mean_absolute_error: 0.5681
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4845 - mean_absolute_error: 0.5761 - val_loss: 0.4762 - val_mean_absolute_error: 0.5676
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4843 - mean_absolute_error: 0.5756 - val_loss: 0.4761 - val_mean_absolute_error: 0.5671
# Epoch 71/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4842 - mean_absolute_error: 0.5752 - val_loss: 0.4760 - val_mean_absolute_error: 0.5672
# Epoch 72/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4840 - mean_absolute_error: 0.5748 - val_loss: 0.4759 - val_mean_absolute_error: 0.5669
# Epoch 73/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4839 - mean_absolute_error: 0.5744 - val_loss: 0.4758 - val_mean_absolute_error: 0.5667
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4839 - mean_absolute_error: 0.5744 - val_loss: 0.4757 - val_mean_absolute_error: 0.5664
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4837 - mean_absolute_error: 0.5740 - val_loss: 0.4756 - val_mean_absolute_error: 0.5663
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4836 - mean_absolute_error: 0.5737 - val_loss: 0.4754 - val_mean_absolute_error: 0.5657
# Epoch 77/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4835 - mean_absolute_error: 0.5736 - val_loss: 0.4754 - val_mean_absolute_error: 0.5656
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4834 - mean_absolute_error: 0.5733 - val_loss: 0.4753 - val_mean_absolute_error: 0.5656
# Epoch 79/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4834 - mean_absolute_error: 0.5732 - val_loss: 0.4753 - val_mean_absolute_error: 0.5652
# Epoch 80/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4833 - mean_absolute_error: 0.5729 - val_loss: 0.4751 - val_mean_absolute_error: 0.5649
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4832 - mean_absolute_error: 0.5725 - val_loss: 0.4751 - val_mean_absolute_error: 0.5650
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4831 - mean_absolute_error: 0.5725 - val_loss: 0.4750 - val_mean_absolute_error: 0.5651
# Epoch 83/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4831 - mean_absolute_error: 0.5724 - val_loss: 0.4750 - val_mean_absolute_error: 0.5650
# Epoch 84/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4830 - mean_absolute_error: 0.5719 - val_loss: 0.4749 - val_mean_absolute_error: 0.5647
# Epoch 85/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4829 - mean_absolute_error: 0.5718 - val_loss: 0.4749 - val_mean_absolute_error: 0.5647
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4829 - mean_absolute_error: 0.5716 - val_loss: 0.4748 - val_mean_absolute_error: 0.5645
# Epoch 87/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4828 - mean_absolute_error: 0.5714 - val_loss: 0.4748 - val_mean_absolute_error: 0.5646
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4827 - mean_absolute_error: 0.5711 - val_loss: 0.4748 - val_mean_absolute_error: 0.5643
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4826 - mean_absolute_error: 0.5710 - val_loss: 0.4746 - val_mean_absolute_error: 0.5640
# Epoch 90/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4826 - mean_absolute_error: 0.5708 - val_loss: 0.4746 - val_mean_absolute_error: 0.5637
# Epoch 91/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4826 - mean_absolute_error: 0.5706 - val_loss: 0.4745 - val_mean_absolute_error: 0.5633
# Epoch 92/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4825 - mean_absolute_error: 0.5705 - val_loss: 0.4745 - val_mean_absolute_error: 0.5634
# Epoch 93/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4824 - mean_absolute_error: 0.5703 - val_loss: 0.4745 - val_mean_absolute_error: 0.5635
# Epoch 94/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4824 - mean_absolute_error: 0.5703 - val_loss: 0.4742 - val_mean_absolute_error: 0.5630
# Epoch 95/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4823 - mean_absolute_error: 0.5700 - val_loss: 0.4742 - val_mean_absolute_error: 0.5630
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4823 - mean_absolute_error: 0.5698 - val_loss: 0.4743 - val_mean_absolute_error: 0.5631
# Epoch 97/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4822 - mean_absolute_error: 0.5694 - val_loss: 0.4741 - val_mean_absolute_error: 0.5626
# Epoch 98/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4822 - mean_absolute_error: 0.5694 - val_loss: 0.4742 - val_mean_absolute_error: 0.5631
# Epoch 99/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4822 - mean_absolute_error: 0.5695 - val_loss: 0.4741 - val_mean_absolute_error: 0.5626
# Epoch 100/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4820 - mean_absolute_error: 0.5690 - val_loss: 0.4740 - val_mean_absolute_error: 0.5622
# 7/7 [==============================] - 0s 1000us/step

# %%
# Calculate the Mean Squared Error (MSE) for each sample
# This evaluates the reconstruction error between the original and predicted values
mse_values = [mean_squared_error(real[i], pred[i]) for i in range(len(real))]

# Create a histogram to visualize the distribution of reconstruction errors (MSE)
plt.figure(figsize=(8, 6))
plt.hist(mse_values, bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Reconstruction Errors (MSE)')
plt.xlabel('Mean Squared Error (MSE)')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculate the total reconstruction error for each sample (sum of errors across all features)
# This calculates how far the original data is from the reconstructed data for each sample
total_error = np.sum((real - pred) ** 2, axis=1)

# Create a plot to visualize the total reconstruction error for each sample
# Low error across many samples indicates a good reconstruction of data
# Spikes (high error) may indicate problematic samples or data anomalies
plt.figure(figsize=(10, 5))
plt.plot(total_error, label='Total Reconstruction Error')
plt.title('Total Reconstruction Error for Each Sample')
plt.xlabel('Samples')
plt.ylabel('Total Error')
plt.legend()
plt.show()
